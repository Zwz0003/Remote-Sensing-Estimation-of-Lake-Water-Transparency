# %% [markdown]
# <a href="https://colab.research.google.com/github/Zwz0003/Remote-Sensing-Estimation-of-Lake-Water-Transparency/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Environment configuration - Google cloud disk loading

# %%
import sys
from google.colab import drive
drive.mount('/content/drive')
sys.path.append('/content/drive/My Drive/Graduationproject')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Environment configuration - Gee

# %%
# !pip install earthengine-api
# !earthengine authenticate --quiet

# %% [markdown]
# Environment configuration - other required libraries

# %%
# !pip install pandas
# !pip install ipygee
# !pip install pyproj

# %% [markdown]
# Main program

# %%
import ee
ee.Initialize()

import os 
os.chdir("/content/drive/MyDrive/Graduationproject/acolite-main")

# %%
import acolite as ac

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

input = "/content/drive/MyDrive/Graduationproject/input_nc"
output_nc = "/content/drive/MyDrive/Graduationproject/output_acolite"
output_csv = "/content/drive/MyDrive/Graduationproject/output_csv"
sources = ['Landsat 8']
point_list_dir = "/content/drive/MyDrive/Graduationproject/coordinates_Fourlakes_test.csv"
sdate = "2013-01"
edate = "2022-08"

ac.acolite_gee_run.acolite_gee_run(input, output_nc, output_csv, sources, point_list_dir, sdate, edate)
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Wrote lon
# Writing lat
# Wrote lat
# Writing sza
# Wrote sza
# Writing vza
# Wrote vza
# Writing raa
# Wrote raa
# Loading LUTs
# romix+rsky_t True
# Loading LUTs took 2.8 s
# 1 rhot_443
# 1 intercept 0.094
# L8_OLI/B1 ACOLITE-LUT-202110-MOD1 took 0.023s (StdLUT)
# L8_OLI/B1 ACOLITE-LUT-202110-MOD2 took 0.020s (StdLUT)
# 2 rhot_483
# 2 intercept 0.074
# L8_OLI/B2 ACOLITE-LUT-202110-MOD1 took 0.019s (StdLUT)
# L8_OLI/B2 ACOLITE-LUT-202110-MOD2 took 0.008s (StdLUT)
# 3 rhot_561
# 3 intercept 0.056
# L8_OLI/B3 ACOLITE-LUT-202110-MOD1 took 0.010s (StdLUT)
# L8_OLI/B3 ACOLITE-LUT-202110-MOD2 took 0.020s (StdLUT)
# 4 rhot_655
# 4 intercept 0.032
# L8_OLI/B4 ACOLITE-LUT-202110-MOD1 took 0.024s (StdLUT)
# L8_OLI/B4 ACOLITE-LUT-202110-MOD2 took 0.012s (StdLUT)
# 5 rhot_865
# 5 intercept 0.014
# L8_OLI/B5 ACOLITE-LUT-202110-MOD1 took 0.021s (StdLUT)
# L8_OLI/B5 ACOLITE-LUT-202110-MOD2 took 0.024s (StdLUT)
# 6 rhot_1609
# 6 intercept 0.003
# L8_OLI/B6 ACOLITE-LUT-202110-MOD1 took 0.008s (StdLUT)
# L8_OLI/B6 ACOLITE-LUT-202110-MOD2 took 0.009s (StdLUT)
# 7 rhot_2201
# 7 intercept 0.002
# L8_OLI/B7 ACOLITE-LUT-202110-MOD1 took 0.008s (StdLUT)
# L8_OLI/B7 ACOLITE-LUT-202110-MOD2 took 0.016s (StdLUT)
# 8 rhot_592
# 8 intercept 0.047
# L8_OLI/B8 ACOLITE-LUT-202110-MOD1 took 0.011s (StdLUT)
# L8_OLI/B8 ACOLITE-LUT-202110-MOD2 took 0.008s (StdLUT)
# Choosing best fitting model: min_drmsd (2 bands)
# Computing RMSD for model ACOLITE-LUT-202110-MOD1
# Computing RMSD for model ACOLITE-LUT-202110-MOD1: 1.1383e-03
# Computing RMSD for model ACOLITE-LUT-202110-MOD2
# Computing RMSD for model ACOLITE-LUT-202110-MOD2: 6.5179e-05
# Selected model ACOLITE-LUT-202110-MOD2: aot 0.076, RMSD 6.52e-05
# Reshaping pressure to 101x101
# Reshaping wind to 101x101
# use_revlut True
# Wrote rhot_443
# Computing surface reflectance 1 443 0.998
# Wrote rhos_443
# L8_OLI/B1 took 0.3s (RevLUT)
# Wrote rhot_483
# Computing surface reflectance 2 483 0.986
# Wrote rhos_483
# L8_OLI/B2 took 0.3s (RevLUT)
# Wrote rhot_561
# Computing surface reflectance 3 561 0.926
# Wrote rhos_561
# L8_OLI/B3 took 0.3s (RevLUT)
# Wrote rhot_655
# Computing surface reflectance 4 655 0.949
# Wrote rhos_655
# L8_OLI/B4 took 0.3s (RevLUT)
# Wrote rhot_865
# Computing surface reflectance 5 865 0.996
# Wrote rhos_865
# L8_OLI/B5 took 0.3s (RevLUT)
# Wrote rhot_1609
# Computing surface reflectance 6 1609 0.962
# Wrote rhos_1609
# L8_OLI/B6 took 0.3s (RevLUT)
# Wrote rhot_2201
# Computing surface reflectance 7 2201 0.916
# Wrote rhos_2201
# L8_OLI/B7 took 0.3s (RevLUT)
# Wrote rhot_592
# Computing surface reflectance 8 592 0.935
# Wrote rhos_592
# L8_OLI/B8 took 0.3s (RevLUT)
# Wrote rhot_1373
# Computing orange band
# Wrote rhos_613
# Wrote /content/drive/MyDrive/Graduationproject/output_acolite/L8_OLI_2022_03_10_03_46_55_131042_GEM_L2R.nc
# Writing lon
# Writing lat
# Writing Rrs_443
# Writing Rrs_483
# Writing Rrs_561
# Writing Rrs_655
# Writing Rrs_865
# Writing Rrs_1609
# Writing Rrs_2201
# Writing Rrs_592
# Writing Rrs_613
# gem.data <bound method gem.data of <acolite.gem.gem.gem object at 0x7f2f86ed0ad0>>
# gem.datasets ['lon', 'lat', 'saa', 'sza', 'vaa', 'vza', 'raa', 'rhot_443', 'rhot_483', 'rhot_561', 'rhot_655', 'rhot_865', 'rhot_1609', 'rhot_2201', 'rhot_592', 'rhot_1373', 'bt10', 'bt11']
# Running acolite for /content/drive/MyDrive/Graduationproject/input_nc/25N939853_100E175298_100px/L8_OLI_2022_04_11_03_46_45_131042_GEM_L1R.nc
# gem.gatts {'generated_by': 'ACOLITE', 'generated_on': '2022-09-04 05:38:48 UTC', 'contact': 'Quinten Vanhellemont', 'product_type': 'NetCDF', 'metadata_profile': 'beam', 'metadata_version': '0.5', 'auto_grouping': 'rhot:rhorc:rhos:rhow:Rrs', 'Conventions': 'CF-1.7', 'sensor': 'L8_OLI', 'vza': 0, 'sza': 28.332069500000003, 'raa': 27.257162, 'isodate': '2022-04-11T03:46:45.826172+00:00', 'pid': 'LC08_L1TP_131042_20220411_20220419_02_T1', 'se_distance': 1.002050297917322, 'oname': 'L8_OLI_2022_04_11_03_46_45', 'ofile': '/content/drive/MyDrive/Graduationproject/input_nc/25N939853_100E175298_100px/L8_OLI_2022_04_11_03_46_45_131042_GEM_L1R.nc', 'CLOUD_COVER': 27.93, 'CLOUD_COVER_LAND': 27.93, 'COLLECTION_CATEGORY': 'T1', 'COLLECTION_NUMBER': 2, 'DATA_SOURCE_ELEVATION': 'GLS2000', 'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS', 'DATE_ACQUIRED': '2022-04-11', 'DATE_PRODUCT_GENERATED': 1650396881000, 'DATUM': 'WGS84', 'EARTH_SUN_DISTANCE': 1.0019757, 'ELLIPSOID': 'WGS84', 'GEOMETRIC_RMSE_MODEL': 7.162, 'GEOMETRIC_RMSE_MODEL_X': 4.408, 'GEOMETRIC_RMSE_MODEL_Y': 5.645, 'GEOMETRIC_RMSE_VERIFY': 4.764, 'GRID_CELL_SIZE_PANCHROMATIC': 15, 'GRID_CELL_SIZE_REFLECTIVE': 30, 'GRID_CELL_SIZE_THERMAL': 30, 'GROUND_CONTROL_POINTS_MODEL': 514, 'GROUND_CONTROL_POINTS_VERIFY': 143, 'GROUND_CONTROL_POINTS_VERSION': 5, 'IMAGE_QUALITY_OLI': 9, 'IMAGE_QUALITY_TIRS': 9, 'K1_CONSTANT_BAND_10': 774.8853, 'K1_CONSTANT_BAND_11': 480.8883, 'K2_CONSTANT_BAND_10': 1321.0789, 'K2_CONSTANT_BAND_11': 1201.1442, 'LANDSAT_PRODUCT_ID': 'LC08_L1TP_131042_20220411_20220419_02_T1', 'LANDSAT_SCENE_ID': 'LC81310422022101LGN00', 'MAP_PROJECTION': 'UTM', 'NADIR_OFFNADIR': 'NADIR', 'ORIENTATION': 'NORTH_UP', 'PANCHROMATIC_LINES': 15461, 'PANCHROMATIC_SAMPLES': 15161, 'PROCESSING_LEVEL': 'L1TP', 'PROCESSING_SOFTWARE_VERSION': 'LPGS_15.6.0', 'RADIANCE_ADD_BAND_1': -62.53144, 'RADIANCE_ADD_BAND_10': 0.1, 'RADIANCE_ADD_BAND_11': 0.1, 'RADIANCE_ADD_BAND_2': -64.03296, 'RADIANCE_ADD_BAND_3': -59.00583, 'RADIANCE_ADD_BAND_4': -49.75704, 'RADIANCE_ADD_BAND_5': -30.44883, 'RADIANCE_ADD_BAND_6': -7.57235, 'RADIANCE_ADD_BAND_7': -2.55229, 'RADIANCE_ADD_BAND_8': -56.31127, 'RADIANCE_ADD_BAND_9': -11.90009, 'RADIANCE_MULT_BAND_1': 0.012506, 'RADIANCE_MULT_BAND_10': 0.0003342, 'RADIANCE_MULT_BAND_11': 0.0003342, 'RADIANCE_MULT_BAND_2': 0.012807, 'RADIANCE_MULT_BAND_3': 0.011801, 'RADIANCE_MULT_BAND_4': 0.0099514, 'RADIANCE_MULT_BAND_5': 0.0060898, 'RADIANCE_MULT_BAND_6': 0.0015145, 'RADIANCE_MULT_BAND_7': 0.00051046, 'RADIANCE_MULT_BAND_8': 0.011262, 'RADIANCE_MULT_BAND_9': 0.00238, 'REFLECTANCE_ADD_BAND_1': -0.1, 'REFLECTANCE_ADD_BAND_2': -0.1, 'REFLECTANCE_ADD_BAND_3': -0.1, 'REFLECTANCE_ADD_BAND_4': -0.1, 'REFLECTANCE_ADD_BAND_5': -0.1, 'REFLECTANCE_ADD_BAND_6': -0.1, 'REFLECTANCE_ADD_BAND_7': -0.1, 'REFLECTANCE_ADD_BAND_8': -0.1, 'REFLECTANCE_ADD_BAND_9': -0.1, 'REFLECTANCE_MULT_BAND_1': 2e-05, 'REFLECTANCE_MULT_BAND_2': 2e-05, 'REFLECTANCE_MULT_BAND_3': 2e-05, 'REFLECTANCE_MULT_BAND_4': 2e-05, 'REFLECTANCE_MULT_BAND_5': 2e-05, 'REFLECTANCE_MULT_BAND_6': 2e-05, 'REFLECTANCE_MULT_BAND_7': 2e-05, 'REFLECTANCE_MULT_BAND_8': 2e-05, 'REFLECTANCE_MULT_BAND_9': 2e-05, 'REFLECTIVE_LINES': 7731, 'REFLECTIVE_SAMPLES': 7581, 'REQUEST_ID': 'P701dbc08nslc_00035', 'RESAMPLING_OPTION': 'CUBIC_CONVOLUTION', 'ROLL_ANGLE': -0.001, 'SATURATION_BAND_1': 'N', 'SATURATION_BAND_2': 'N', 'SATURATION_BAND_3': 'Y', 'SATURATION_BAND_4': 'Y', 'SATURATION_BAND_5': 'Y', 'SATURATION_BAND_6': 'Y', 'SATURATION_BAND_7': 'Y', 'SATURATION_BAND_8': 'N', 'SATURATION_BAND_9': 'N', 'SCENE_CENTER_TIME': '03:46:45.8261729Z', 'SENSOR_ID': 'OLI_TIRS', 'SPACECRAFT_ID': 'LANDSAT_8', 'STATION_ID': 'LGN', 'SUN_AZIMUTH': 124.50231317, 'SUN_ELEVATION': 61.6679305, 'TARGET_WRS_PATH': 131, 'TARGET_WRS_ROW': 42, 'THERMAL_LINES': 7731, 'THERMAL_SAMPLES': 7581, 'TIRS_SSM_MODEL': 'FINAL', 'TIRS_SSM_POSITION_STATUS': 'ESTIMATED', 'TRUNCATION_OLI': 'UPPER', 'UTM_ZONE': 47, 'WRS_PATH': 131, 'WRS_ROW': 42, 'WRS_TYPE': 2, 'system:asset_size':  ...
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202210100_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202210106_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202210112_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202210118_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202210200_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202210100_O3_AURAOMI_24h.hdf
# gem.datasets ['lon', 'lat', 'saa', 'sza', 'vaa', 'vza', 'raa', 'rhot_443', 'rhot_483', 'rhot_561', 'rhot_655', 'rhot_865', 'rhot_1609', 'rhot_2201', 'rhot_592', 'rhot_1373', 'bt10', 'bt11']
# geom_mean {'sza': 28.40307, 'vza': 1.1459111, 'raa': 28.721289, 'pressure': 1013.25, 'wind': 2.0}
# tg_dict {'wave': {'1': 442.98228442313956, '2': 482.58886817501445, '3': 561.332141645918, '4': 654.6055091346833, '5': 864.5708275848937, '6': 1609.090508782215, '7': 2201.2483359785456, '8': 591.6667966035536, '9': 1373.4761690438504}, 'tt_h2o': {'1': 0.9999999999999999, '2': 0.9999999999999998, '3': 0.9951367593850478, '4': 0.9906050466994557, '5': 0.9980220771378712, '6': 0.9980252142906096, '7': 0.9655283334164823, '8': 0.9933791667113853, '9': 0.008016828441828128}, 'tt_o3': {'1': 0.9981537385881026, '2': 0.9873812895265136, '3': 0.9354872814829507, '4': 0.9612567145250622, '5': 0.9985714426451365, '6': 1.0, '7': 1.0, '8': 0.9451710895552285, '9': 1.0}, 'tt_o2': {'1': 1.0, '2': 1.0, '3': 1.0, '4': 0.9999911452139273, '5': 0.9999549502641132, '6': 1.0, '7': 1.0, '8': 0.9996160731613698, '9': 1.0}, 'tt_co2': {'1': 1.0, '2': 1.0, '3': 1.0, '4': 1.0, '5': 1.0, '6': 0.9724718549176277, '7': 0.9990529364189057, '8': 1.0, '9': 0.999978432364181}, 'tt_n2o': {'1': 1.0, '2': 1.0, '3': 1.0, '4': 1.0, '5': 1.0, '6': 1.0, '7': 0.996309153527554, '8': 1.0, '9': 1.0}, 'tt_ch4': {'1': 1.0, '2': 1.0, '3': 1.0, '4': 1.0, '5': 1.0, '6': 0.9935271663900932, '7': 0.9577508855504459, '8': 1.0, '9': 1.0}, 'tt_gas': {'1': 0.9981537385881025, '2': 0.9873812895265134, '3': 0.9309884297459213, '4': 0.9522328793716873, '5': 0.9965527697146086, '6': 0.9641350324454518, '7': 0.9196433995607949, '8': 0.938609888758685, '9': 0.00801650997019457}}
# Using DSF atmospheric correction
# Scene too small for tiling (1x1 tiles of 200x200 pixels), using fixed processing
# Writing lon
# Wrote lon
# Writing lat
# Wrote lat
# Writing sza
# Wrote sza
# Writing vza
# Wrote vza
# Writing raa
# Wrote raa
# Loading LUTs
# romix+rsky_t True
# Loading LUTs took 2.8 s
# 1 rhot_443
# 1 intercept 0.103
# L8_OLI/B1 ACOLITE-LUT-202110-MOD1 took 0.008s (StdLUT)
# L8_OLI/B1 ACOLITE-LUT-202110-MOD2 took 0.012s (StdLUT)
# 2 rhot_483
# 2 intercept 0.084
# L8_OLI/B2 ACOLITE-LUT-202110-MOD1 took 0.009s (StdLUT)
# L8_OLI/B2 ACOLITE-LUT-202110-MOD2 took 0.011s (StdLUT)
# 3 rhot_561
# 3 intercept 0.066
# L8_OLI/B3 ACOLITE-LUT-202110-MOD1 took 0.022s (StdLUT)
# L8_OLI/B3 ACOLITE-LUT-202110-MOD2 took 0.017s (StdLUT)
# 4 rhot_655
# 4 intercept 0.043
# L8_OLI/B4 ACOLITE-LUT-202110-MOD1 took 0.020s (StdLUT)
# L8_OLI/B4 ACOLITE-LUT-202110-MOD2 took 0.034s (StdLUT)
# 5 rhot_865
# 5 intercept 0.029
# L8_OLI/B5 ACOLITE-LUT-202110-MOD1 took 0.024s (StdLUT)
# L8_OLI/B5 ACOLITE-LUT-202110-MOD2 took 0.010s (StdLUT)
# 6 rhot_1609
# 6 intercept 0.010
# L8_OLI/B6 ACOLITE-LUT-202110-MOD1 took 0.026s (StdLUT)
# L8_OLI/B6 ACOLITE-LUT-202110-MOD2 took 0.012s (StdLUT)
# 7 rhot_2201
# 7 intercept 0.006
# L8_OLI/B7 ACOLITE-LUT-202110-MOD1 took 0.022s (StdLUT)
# L8_OLI/B7 ACOLITE-LUT-202110-MOD2 took 0.026s (StdLUT)
# 8 rhot_592
# 8 intercept 0.058
# L8_OLI/B8 ACOLITE-LUT-202110-MOD1 took 0.023s (StdLUT)
# L8_OLI/B8 ACOLITE-LUT-202110-MOD2 took 0.023s (StdLUT)
# Choosing best fitting model: min_drmsd (2 bands)
# Computing RMSD for model ACOLITE-LUT-202110-MOD1
# Computing RMSD for model ACOLITE-LUT-202110-MOD1: 6.3614e-03
# Computing RMSD for model ACOLITE-LUT-202110-MOD2
# Computing RMSD for model ACOLITE-LUT-202110-MOD2: 2.7869e-03
# Selected model ACOLITE-LUT-202110-MOD2: aot 0.147, RMSD 2.79e-03
# Reshaping pressure to 101x101
# Reshaping wind to 101x101
# use_revlut True
# Wrote rhot_443
# Computing surface reflectance 1 443 0.998
# Wrote rhos_443
# L8_OLI/B1 took 0.3s (RevLUT)
# Wrote rhot_483
# Computing surface reflectance 2 483 0.987
# Wrote rhos_483
# L8_OLI/B2 took 0.3s (RevLUT)
# Wrote rhot_561
# Computing surface reflectance 3 561 0.931
# Wrote rhos_561
# L8_OLI/B3 took 0.3s (RevLUT)
# Wrote rhot_655
# Computing surface reflectance 4 655 0.952
# Wrote rhos_655
# L8_OLI/B4 took 0.3s (RevLUT)
# Wrote rhot_865
# Computing surface reflectance 5 865 0.997
# Wrote rhos_865
# L8_OLI/B5 took 0.3s (RevLUT)
# Wrote rhot_1609
# Computing surface reflectance 6 1609 0.964
# Wrote rhos_1609
# L8_OLI/B6 took 0.3s (RevLUT)
# Wrote rhot_2201
# Computing surface reflectance 7 2201 0.920
# Wrote rhos_2201
# L8_OLI/B7 took 0.3s (RevLUT)
# Wrote rhot_592
# Computing surface reflectance 8 592 0.939
# Wrote rhos_592
# L8_OLI/B8 took 0.3s (RevLUT)
# Wrote rhot_1373
# Computing orange band
# Wrote rhos_613
# Wrote /content/drive/MyDrive/Graduationproject/output_acolite/L8_OLI_2022_04_11_03_46_45_131042_GEM_L2R.nc
# Writing lon
# Writing lat
# Writing Rrs_443
# Writing Rrs_483
# Writing Rrs_561
# Writing Rrs_655
# Writing Rrs_865
# Writing Rrs_1609
# Writing Rrs_2201
# Writing Rrs_592
# Writing Rrs_613
# gem.data <bound method gem.data of <acolite.gem.gem.gem object at 0x7f2f7866c4d0>>
# gem.datasets ['lon', 'lat', 'saa', 'sza', 'vaa', 'vza', 'raa', 'rhot_443', 'rhot_483', 'rhot_561', 'rhot_655', 'rhot_865', 'rhot_1609', 'rhot_2201', 'rhot_592', 'rhot_1373', 'bt10', 'bt11']
# Running acolite for /content/drive/MyDrive/Graduationproject/input_nc/25N939853_100E175298_100px/L8_OLI_2022_04_27_03_46_42_131042_GEM_L1R.nc
# gem.gatts {'generated_by': 'ACOLITE', 'generated_on': '2022-09-04 05:38:50 UTC', 'contact': 'Quinten Vanhellemont', 'product_type': 'NetCDF', 'metadata_profile': 'beam', 'metadata_version': '0.5', 'auto_grouping': 'rhot:rhorc:rhos:rhow:Rrs', 'Conventions': 'CF-1.7', 'sensor': 'L8_OLI', 'vza': 0, 'sza': 24.25698629, 'raa': 22.671322, 'isodate': '2022-04-27T03:46:42.666101+00:00', 'pid': 'LC08_L1TP_131042_20220427_20220503_02_T1', 'se_distance': 1.0064635022677988, 'oname': 'L8_OLI_2022_04_27_03_46_42', 'ofile': '/content/drive/MyDrive/Graduationproject/input_nc/25N939853_100E175298_100px/L8_OLI_2022_04_27_03_46_42_131042_GEM_L1R.nc', 'CLOUD_COVER': 12.87, 'CLOUD_COVER_LAND': 12.87, 'COLLECTION_CATEGORY': 'T1', 'COLLECTION_NUMBER': 2, 'DATA_SOURCE_ELEVATION': 'GLS2000', 'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS', 'DATE_ACQUIRED': '2022-04-27', 'DATE_PRODUCT_GENERATED': 1651610760000, 'DATUM': 'WGS84', 'EARTH_SUN_DISTANCE': 1.006425, 'ELLIPSOID': 'WGS84', 'GEOMETRIC_RMSE_MODEL': 7.701, 'GEOMETRIC_RMSE_MODEL_X': 4.429, 'GEOMETRIC_RMSE_MODEL_Y': 6.3, 'GEOMETRIC_RMSE_VERIFY': 6.09, 'GRID_CELL_SIZE_PANCHROMATIC': 15, 'GRID_CELL_SIZE_REFLECTIVE': 30, 'GRID_CELL_SIZE_THERMAL': 30, 'GROUND_CONTROL_POINTS_MODEL': 565, 'GROUND_CONTROL_POINTS_VERIFY': 169, 'GROUND_CONTROL_POINTS_VERSION': 5, 'IMAGE_QUALITY_OLI': 9, 'IMAGE_QUALITY_TIRS': 9, 'K1_CONSTANT_BAND_10': 774.8853, 'K1_CONSTANT_BAND_11': 480.8883, 'K2_CONSTANT_BAND_10': 1321.0789, 'K2_CONSTANT_BAND_11': 1201.1442, 'LANDSAT_PRODUCT_ID': 'LC08_L1TP_131042_20220427_20220503_02_T1', 'LANDSAT_SCENE_ID': 'LC81310422022117LGN00', 'MAP_PROJECTION': 'UTM', 'NADIR_OFFNADIR': 'NADIR', 'ORIENTATION': 'NORTH_UP', 'PANCHROMATIC_LINES': 15461, 'PANCHROMATIC_SAMPLES': 15161, 'PROCESSING_LEVEL': 'L1TP', 'PROCESSING_SOFTWARE_VERSION': 'LPGS_15.6.0', 'RADIANCE_ADD_BAND_1': -61.97978, 'RADIANCE_ADD_BAND_10': 0.1, 'RADIANCE_ADD_BAND_11': 0.1, 'RADIANCE_ADD_BAND_2': -63.46805, 'RADIANCE_ADD_BAND_3': -58.48526, 'RADIANCE_ADD_BAND_4': -49.31807, 'RADIANCE_ADD_BAND_5': -30.1802, 'RADIANCE_ADD_BAND_6': -7.50554, 'RADIANCE_ADD_BAND_7': -2.52977, 'RADIANCE_ADD_BAND_8': -55.81448, 'RADIANCE_ADD_BAND_9': -11.79511, 'RADIANCE_MULT_BAND_1': 0.012396, 'RADIANCE_MULT_BAND_10': 0.0003342, 'RADIANCE_MULT_BAND_11': 0.0003342, 'RADIANCE_MULT_BAND_2': 0.012694, 'RADIANCE_MULT_BAND_3': 0.011697, 'RADIANCE_MULT_BAND_4': 0.0098636, 'RADIANCE_MULT_BAND_5': 0.006036, 'RADIANCE_MULT_BAND_6': 0.0015011, 'RADIANCE_MULT_BAND_7': 0.00050595, 'RADIANCE_MULT_BAND_8': 0.011163, 'RADIANCE_MULT_BAND_9': 0.002359, 'REFLECTANCE_ADD_BAND_1': -0.1, 'REFLECTANCE_ADD_BAND_2': -0.1, 'REFLECTANCE_ADD_BAND_3': -0.1, 'REFLECTANCE_ADD_BAND_4': -0.1, 'REFLECTANCE_ADD_BAND_5': -0.1, 'REFLECTANCE_ADD_BAND_6': -0.1, 'REFLECTANCE_ADD_BAND_7': -0.1, 'REFLECTANCE_ADD_BAND_8': -0.1, 'REFLECTANCE_ADD_BAND_9': -0.1, 'REFLECTANCE_MULT_BAND_1': 2e-05, 'REFLECTANCE_MULT_BAND_2': 2e-05, 'REFLECTANCE_MULT_BAND_3': 2e-05, 'REFLECTANCE_MULT_BAND_4': 2e-05, 'REFLECTANCE_MULT_BAND_5': 2e-05, 'REFLECTANCE_MULT_BAND_6': 2e-05, 'REFLECTANCE_MULT_BAND_7': 2e-05, 'REFLECTANCE_MULT_BAND_8': 2e-05, 'REFLECTANCE_MULT_BAND_9': 2e-05, 'REFLECTIVE_LINES': 7731, 'REFLECTIVE_SAMPLES': 7581, 'REQUEST_ID': 'P701e4i1g5mah_00035', 'RESAMPLING_OPTION': 'CUBIC_CONVOLUTION', 'ROLL_ANGLE': -0.001, 'SATURATION_BAND_1': 'Y', 'SATURATION_BAND_2': 'Y', 'SATURATION_BAND_3': 'Y', 'SATURATION_BAND_4': 'Y', 'SATURATION_BAND_5': 'Y', 'SATURATION_BAND_6': 'Y', 'SATURATION_BAND_7': 'Y', 'SATURATION_BAND_8': 'N', 'SATURATION_BAND_9': 'N', 'SCENE_CENTER_TIME': '03:46:42.6661010Z', 'SENSOR_ID': 'OLI_TIRS', 'SPACECRAFT_ID': 'LANDSAT_8', 'STATION_ID': 'LGN', 'SUN_AZIMUTH': 115.82533397, 'SUN_ELEVATION': 65.74301371, 'TARGET_WRS_PATH': 131, 'TARGET_WRS_ROW': 42, 'THERMAL_LINES': 7731, 'THERMAL_SAMPLES': 7581, 'TIRS_SSM_MODEL': 'FINAL', 'TIRS_SSM_POSITION_STATUS': 'ESTIMATED', 'TRUNCATION_OLI': 'UPPER', 'UTM_ZONE': 47, 'WRS_PATH': 131, 'WRS_ROW': 42, 'WRS_TYPE': 2, 'system:asset_size': 1307793560 ...
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202211700_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202211706_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202211712_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202211718_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202211800_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202211700_O3_AURAOMI_24h.hdf
# gem.datasets ['lon', 'lat', 'saa', 'sza', 'vaa', 'vza', 'raa', 'rhot_443', 'rhot_483', 'rhot_561', 'rhot_655', 'rhot_865', 'rhot_1609', 'rhot_2201', 'rhot_592', 'rhot_1373', 'bt10', 'bt11']
# geom_mean {'sza': 24.378794, 'vza': 1.7074709, 'raa': 15.314696, 'pressure': 1013.25, 'wind': 2.0}
# tg_dict {'wave': {'1': 442.98228442313956, '2': 482.58886817501445, '3': 561.332141645918, '4': 654.6055091346833, '5': 864.5708275848937, '6': 1609.090508782215, '7': 2201.2483359785456, '8': 591.6667966035536, '9': 1373.4761690438504}, 'tt_h2o': {'1': 0.9999999999999999, '2': 0.9999999999999998, '3': 0.9952306967267023, '4': 0.9907883903821926, '5': 0.9980640300643318, '6': 0.9980677859152726, '7': 0.9660954342585981, '8': 0.9935071647929827, '9': 0.008360986828161322}, 'tt_o3': {'1': 0.9981871525415628, '2': 0.9876079304659402, '3': 0.9366168693344231, '4': 0.9619444897192709, '5': 0.9985973001881006, '6': 1.0, '7': 1.0, '8': 0.94613369301799, '9': 1.0}, 'tt_o2': {'1': 1.0, '2': 1.0, '3': 1.0, '4': 0.999991341426788, '5': 0.9999557745359909, '6': 1.0, '7': 1.0, '8': 0.9996211406409904, '9': 1.0}, 'tt_co2': {'1': 1.0, '2': 1.0, '3': 1.0, '4': 1.0, '5': 1.0, '6': 0.9728527697644559, '7': 0.9990666275382672, '8': 1.0, '9': 0.9999788309601852}, 'tt_n2o': {'1': 1.0, '2': 1.0, '3': 1.0, '4': 1.0, '5': 1.0, '6': 1.0, '7': 0.9963740175032382, '8': 1.0, '9': 1.0}, 'tt_ch4': {'1': 1.0, '2': 1.0, '3': 1.0, '4': 1.0, '5': 1.0, '6': 0.9936333349415241, '7': 0.9583768765369164, '8': 1.0, '9': 1.0}, 'tt_gas': {'1': 0.9981871525415628, '2': 0.9876079304659402, '3': 0.9321986755893888, '4': 0.9530901569116516, '5': 0.9966212373550151, '6': 0.9646609025233602, '7': 0.920883129767103, '8': 0.9396895215136631, '9': 0.00836066228908622}}
# Using DSF atmospheric correction
# Scene too small for tiling (1x1 tiles of 200x200 pixels), using fixed processing
# Writing lon
# Wrote lon
# Writing lat
# Wrote lat
# Writing sza
# Wrote sza
# Writing vza
# Wrote vza
# Writing raa
# Wrote raa
# Loading LUTs
# romix+rsky_t True
# Loading LUTs took 2.7 s
# 1 rhot_443
# 1 intercept 0.114
# L8_OLI/B1 ACOLITE-LUT-202110-MOD1 took 0.026s (StdLUT)
# L8_OLI/B1 ACOLITE-LUT-202110-MOD2 took 0.025s (StdLUT)
# 2 rhot_483
# 2 intercept 0.095
# L8_OLI/B2 ACOLITE-LUT-202110-MOD1 took 0.024s (StdLUT)
# L8_OLI/B2 ACOLITE-LUT-202110-MOD2 took 0.016s (StdLUT)
# 3 rhot_561
# 3 intercept 0.080
# L8_OLI/B3 ACOLITE-LUT-202110-MOD1 took 0.025s (StdLUT)
# L8_OLI/B3 ACOLITE-LUT-202110-MOD2 took 0.020s (StdLUT)
# 4 rhot_655
# 4 intercept 0.057
# L8_OLI/B4 ACOLITE-LUT-202110-MOD1 took 0.009s (StdLUT)
# L8_OLI/B4 ACOLITE-LUT-202110-MOD2 took 0.010s (StdLUT)
# 5 rhot_865
# 5 intercept 0.039
# L8_OLI/B5 ACOLITE-LUT-202110-MOD1 took 0.017s (StdLUT)
# L8_OLI/B5 ACOLITE-LUT-202110-MOD2 took 0.009s (StdLUT)
# 6 rhot_1609
# 6 intercept 0.015
# L8_OLI/B6 ACOLITE-LUT-202110-MOD1 took 0.013s (StdLUT)
# L8_OLI/B6 ACOLITE-LUT-202110-MOD2 took 0.010s (StdLUT)
# 7 rhot_2201
# 7 intercept 0.009
# L8_OLI/B7 ACOLITE-LUT-202110-MOD1 took 0.022s (StdLUT)
# L8_OLI/B7 ACOLITE-LUT-202110-MOD2 took 0.009s (StdLUT)
# 8 rhot_592
# 8 intercept 0.072
# L8_OLI/B8 ACOLITE-LUT-202110-MOD1 took 0.021s (StdLUT)
# L8_OLI/B8 ACOLITE-LUT-202110-MOD2 took 0.022s (StdLUT)
# Choosing best fitting model: min_drmsd (2 bands)
# Computing RMSD for model ACOLITE-LUT-202110-MOD1
# Computing RMSD for model ACOLITE-LUT-202110-MOD1: 6.4799e-03
# Computing RMSD for model ACOLITE-LUT-202110-MOD2
# Computing RMSD for model ACOLITE-LUT-202110-MOD2: 1.5494e-03
# Selected model ACOLITE-LUT-202110-MOD2: aot 0.299, RMSD 1.55e-03
# Reshaping pressure to 101x101
# Reshaping wind to 101x101
# use_revlut True
# Wrote rhot_443
# Computing surface reflectance 1 443 0.998
# Wrote rhos_443
# L8_OLI/B1 took 0.3s (RevLUT)
# Wrote rhot_483
# Computing surface reflectance 2 483 0.988
# Wrote rhos_483
# L8_OLI/B2 took 0.3s (RevLUT)
# Wrote rhot_561
# Computing surface reflectance 3 561 0.932
# Wrote rhos_561
# L8_OLI/B3 took 0.3s (RevLUT)
# Wrote rhot_655
# Computing surface reflectance 4 655 0.953
# Wrote rhos_655
# L8_OLI/B4 took 0.3s (RevLUT)
# Wrote rhot_865
# Computing surface reflectance 5 865 0.997
# Wrote rhos_865
# L8_OLI/B5 took 0.3s (RevLUT)
# Wrote rhot_1609
# Computing surface reflectance 6 1609 0.965
# Wrote rhos_1609
# L8_OLI/B6 took 0.3s (RevLUT)
# Wrote rhot_2201
# Computing surface reflectance 7 2201 0.921
# Wrote rhos_2201
# L8_OLI/B7 took 0.3s (RevLUT)
# Wrote rhot_592
# Computing surface reflectance 8 592 0.940
# Wrote rhos_592
# L8_OLI/B8 took 0.3s (RevLUT)
# Wrote rhot_1373
# Computing orange band
# Wrote rhos_613
# Wrote /content/drive/MyDrive/Graduationproject/output_acolite/L8_OLI_2022_04_27_03_46_42_131042_GEM_L2R.nc
# Writing lon
# Writing lat
# Writing Rrs_443
# Writing Rrs_483
# Writing Rrs_561
# Writing Rrs_655
# Writing Rrs_865
# Writing Rrs_1609
# Writing Rrs_2201
# Writing Rrs_592
# Writing Rrs_613
# gem.data <bound method gem.data of <acolite.gem.gem.gem object at 0x7f2f86dd4550>>
# gem.datasets ['lon', 'lat', 'saa', 'sza', 'vaa', 'vza', 'raa', 'rhot_443', 'rhot_483', 'rhot_561', 'rhot_655', 'rhot_865', 'rhot_1609', 'rhot_2201', 'rhot_592', 'rhot_1373', 'bt10', 'bt11']
# Running acolite for /content/drive/MyDrive/Graduationproject/input_nc/25N939853_100E175298_100px/L8_OLI_2022_05_13_03_46_51_131042_GEM_L1R.nc
# gem.gatts {'generated_by': 'ACOLITE', 'generated_on': '2022-09-04 05:38:52 UTC', 'contact': 'Quinten Vanhellemont', 'product_type': 'NetCDF', 'metadata_profile': 'beam', 'metadata_version': '0.5', 'auto_grouping': 'rhot:rhorc:rhos:rhow:Rrs', 'Conventions': 'CF-1.7', 'sensor': 'L8_OLI', 'vza': 0, 'sza': 21.733674199999996, 'raa': 20.22509, 'isodate': '2022-05-13T03:46:51.563494+00:00', 'pid': 'LC08_L1TP_131042_20220513_20220519_02_T1', 'se_distance': 1.010378427814515, 'oname': 'L8_OLI_2022_05_13_03_46_51', 'ofile': '/content/drive/MyDrive/Graduationproject/input_nc/25N939853_100E175298_100px/L8_OLI_2022_05_13_03_46_51_131042_GEM_L1R.nc', 'CLOUD_COVER': 49.96, 'CLOUD_COVER_LAND': 49.96, 'COLLECTION_CATEGORY': 'T1', 'COLLECTION_NUMBER': 2, 'DATA_SOURCE_ELEVATION': 'GLS2000', 'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS', 'DATE_ACQUIRED': '2022-05-13', 'DATE_PRODUCT_GENERATED': 1652936900000, 'DATUM': 'WGS84', 'EARTH_SUN_DISTANCE': 1.0103021, 'ELLIPSOID': 'WGS84', 'GEOMETRIC_RMSE_MODEL': 8.473, 'GEOMETRIC_RMSE_MODEL_X': 5.513, 'GEOMETRIC_RMSE_MODEL_Y': 6.435, 'GEOMETRIC_RMSE_VERIFY': 6.532, 'GRID_CELL_SIZE_PANCHROMATIC': 15, 'GRID_CELL_SIZE_REFLECTIVE': 30, 'GRID_CELL_SIZE_THERMAL': 30, 'GROUND_CONTROL_POINTS_MODEL': 183, 'GROUND_CONTROL_POINTS_VERIFY': 75, 'GROUND_CONTROL_POINTS_VERSION': 5, 'IMAGE_QUALITY_OLI': 9, 'IMAGE_QUALITY_TIRS': 9, 'K1_CONSTANT_BAND_10': 774.8853, 'K1_CONSTANT_BAND_11': 480.8883, 'K2_CONSTANT_BAND_10': 1321.0789, 'K2_CONSTANT_BAND_11': 1201.1442, 'LANDSAT_PRODUCT_ID': 'LC08_L1TP_131042_20220513_20220519_02_T1', 'LANDSAT_SCENE_ID': 'LC81310422022133LGN00', 'MAP_PROJECTION': 'UTM', 'NADIR_OFFNADIR': 'NADIR', 'ORIENTATION': 'NORTH_UP', 'PANCHROMATIC_LINES': 15461, 'PANCHROMATIC_SAMPLES': 15161, 'PROCESSING_LEVEL': 'L1TP', 'PROCESSING_SOFTWARE_VERSION': 'LPGS_15.6.0', 'RADIANCE_ADD_BAND_1': -61.50498, 'RADIANCE_ADD_BAND_10': 0.1, 'RADIANCE_ADD_BAND_11': 0.1, 'RADIANCE_ADD_BAND_2': -62.98185, 'RADIANCE_ADD_BAND_3': -58.03724, 'RADIANCE_ADD_BAND_4': -48.94027, 'RADIANCE_ADD_BAND_5': -29.949, 'RADIANCE_ADD_BAND_6': -7.44805, 'RADIANCE_ADD_BAND_7': -2.51039, 'RADIANCE_ADD_BAND_8': -55.38692, 'RADIANCE_ADD_BAND_9': -11.70475, 'RADIANCE_MULT_BAND_1': 0.012301, 'RADIANCE_MULT_BAND_10': 0.0003342, 'RADIANCE_MULT_BAND_11': 0.0003342, 'RADIANCE_MULT_BAND_2': 0.012596, 'RADIANCE_MULT_BAND_3': 0.011607, 'RADIANCE_MULT_BAND_4': 0.0097881, 'RADIANCE_MULT_BAND_5': 0.0059898, 'RADIANCE_MULT_BAND_6': 0.0014896, 'RADIANCE_MULT_BAND_7': 0.00050208, 'RADIANCE_MULT_BAND_8': 0.011077, 'RADIANCE_MULT_BAND_9': 0.002341, 'REFLECTANCE_ADD_BAND_1': -0.1, 'REFLECTANCE_ADD_BAND_2': -0.1, 'REFLECTANCE_ADD_BAND_3': -0.1, 'REFLECTANCE_ADD_BAND_4': -0.1, 'REFLECTANCE_ADD_BAND_5': -0.1, 'REFLECTANCE_ADD_BAND_6': -0.1, 'REFLECTANCE_ADD_BAND_7': -0.1, 'REFLECTANCE_ADD_BAND_8': -0.1, 'REFLECTANCE_ADD_BAND_9': -0.1, 'REFLECTANCE_MULT_BAND_1': 2e-05, 'REFLECTANCE_MULT_BAND_2': 2e-05, 'REFLECTANCE_MULT_BAND_3': 2e-05, 'REFLECTANCE_MULT_BAND_4': 2e-05, 'REFLECTANCE_MULT_BAND_5': 2e-05, 'REFLECTANCE_MULT_BAND_6': 2e-05, 'REFLECTANCE_MULT_BAND_7': 2e-05, 'REFLECTANCE_MULT_BAND_8': 2e-05, 'REFLECTANCE_MULT_BAND_9': 2e-05, 'REFLECTIVE_LINES': 7731, 'REFLECTIVE_SAMPLES': 7581, 'REQUEST_ID': 'P701eyx9w8uaa_00035', 'RESAMPLING_OPTION': 'CUBIC_CONVOLUTION', 'ROLL_ANGLE': -0.001, 'SATURATION_BAND_1': 'Y', 'SATURATION_BAND_2': 'Y', 'SATURATION_BAND_3': 'Y', 'SATURATION_BAND_4': 'Y', 'SATURATION_BAND_5': 'Y', 'SATURATION_BAND_6': 'Y', 'SATURATION_BAND_7': 'Y', 'SATURATION_BAND_8': 'N', 'SATURATION_BAND_9': 'N', 'SCENE_CENTER_TIME': '03:46:51.5634940Z', 'SENSOR_ID': 'OLI_TIRS', 'SPACECRAFT_ID': 'LANDSAT_8', 'STATION_ID': 'LGN', 'SUN_AZIMUTH': 106.04963657, 'SUN_ELEVATION': 68.2663258, 'TARGET_WRS_PATH': 131, 'TARGET_WRS_ROW': 42, 'THERMAL_LINES': 7731, 'THERMAL_SAMPLES': 7581, 'TIRS_SSM_MODEL': 'FINAL', 'TIRS_SSM_POSITION_STATUS': 'ESTIMATED', 'TRUNCATION_OLI': 'UPPER', 'UTM_ZONE': 47, 'WRS_PATH': 131, 'WRS_ROW': 42, 'WRS_TYPE': 2, 'system:asset_size': 139 ...
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202213300_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202213306_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202213312_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202213318_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202213400_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202213300_O3_AURAOMI_24h.hdf
# gem.datasets ['lon', 'lat', 'saa', 'sza', 'vaa', 'vza', 'raa', 'rhot_443', 'rhot_483', 'rhot_561', 'rhot_655', 'rhot_865', 'rhot_1609', 'rhot_2201', 'rhot_592', 'rhot_1373', 'bt10', 'bt11']
# geom_mean {'sza': 21.866533, 'vza': 1.6414429, 'raa': 26.317019, 'pressure': 1013.25, 'wind': 2.0}
# tg_dict {'wave': {'1': 442.98228442313956, '2': 482.58886817501445, '3': 561.332141645918, '4': 654.6055091346833, '5': 864.5708275848937, '6': 1609.090508782215, '7': 2201.2483359785456, '8': 591.6667966035536, '9': 1373.4761690438504}, 'tt_h2o': {'1': 1.0000000000000002, '2': 1.0000000000000002, '3': 0.9952906096066274, '4': 0.9909053255810765, '5': 0.9980907862411046, '6': 0.9980949362776119, '7': 0.9664571492007907, '8': 0.9935888014115569, '9': 0.008580667000139694}, 'tt_o3': {'1': 0.9982047617452794, '2': 0.9877273961664871, '3': 0.9372127149111932, '4': 0.9623071446487211, '5': 0.9986109271035934, '6': 1.0, '7': 1.0, '8': 0.9466414177382868, '9': 1.0}, 'tt_o2': {'1': 1.0, '2': 1.0, '3': 1.0, '4': 0.9999914401505148, '5': 0.9999561902548849, '6': 1.0, '7': 1.0, '8': 0.9996237014902221, '9': 1.0}, 'tt_co2': {'1': 1.0, '2': 1.0, '3': 1.0, '4': 1.0, '5': 1.0, '6': 0.973045156597644, '7': 0.9990735285865535, '8': 1.0, '9': 0.9999790288697237}, 'tt_n2o': {'1': 1.0, '2': 1.0, '3': 1.0, '4': 1.0, '5': 1.0, '6': 1.0, '7': 0.9964066051165499, '8': 1.0, '9': 1.0}, 'tt_ch4': {'1': 1.0, '2': 1.0, '3': 1.0, '4': 1.0, '5': 1.0, '6': 0.993686769219655, '7': 0.9586927901624053, '8': 1.0, '9': 1.0}, 'tt_gas': {'1': 0.9982047617452798, '2': 0.9877273961664872, '3': 0.9328467709352397, '4': 0.9535617537164253, '5': 0.9966619397745186, '6': 0.9649318301106531, '7': 0.921582786530062, '8': 0.9402722361057951, '9': 0.008580337923556341}}
# Using DSF atmospheric correction
# Scene too small for tiling (1x1 tiles of 200x200 pixels), using fixed processing
# Writing lon
# Wrote lon
# Writing lat
# Wrote lat
# Writing sza
# Wrote sza
# Writing vza
# Wrote vza
# Writing raa
# Wrote raa
# Loading LUTs
# romix+rsky_t True
# Loading LUTs took 3.3 s
# 1 rhot_443
# 1 intercept 0.098
# L8_OLI/B1 ACOLITE-LUT-202110-MOD1 took 0.014s (StdLUT)
# L8_OLI/B1 ACOLITE-LUT-202110-MOD2 took 0.011s (StdLUT)
# 2 rhot_483
# 2 intercept 0.077
# L8_OLI/B2 ACOLITE-LUT-202110-MOD1 took 0.021s (StdLUT)
# L8_OLI/B2 ACOLITE-LUT-202110-MOD2 took 0.022s (StdLUT)
# 3 rhot_561
# 3 intercept 0.054
# L8_OLI/B3 ACOLITE-LUT-202110-MOD1 took 0.022s (StdLUT)
# L8_OLI/B3 ACOLITE-LUT-202110-MOD2 took 0.019s (StdLUT)
# 4 rhot_655
# 4 intercept 0.030
# L8_OLI/B4 ACOLITE-LUT-202110-MOD1 took 0.028s (StdLUT)
# L8_OLI/B4 ACOLITE-LUT-202110-MOD2 took 0.024s (StdLUT)
# 5 rhot_865
# 5 intercept 0.013
# L8_OLI/B5 ACOLITE-LUT-202110-MOD1 took 0.010s (StdLUT)
# L8_OLI/B5 ACOLITE-LUT-202110-MOD2 took 0.021s (StdLUT)
# 6 rhot_1609
# 6 intercept 0.004
# L8_OLI/B6 ACOLITE-LUT-202110-MOD1 took 0.024s (StdLUT)
# L8_OLI/B6 ACOLITE-LUT-202110-MOD2 took 0.023s (StdLUT)
# 7 rhot_2201
# 7 intercept 0.003
# L8_OLI/B7 ACOLITE-LUT-202110-MOD1 took 0.016s (StdLUT)
# L8_OLI/B7 ACOLITE-LUT-202110-MOD2 took 0.023s (StdLUT)
# 8 rhot_592
# 8 intercept 0.045
# L8_OLI/B8 ACOLITE-LUT-202110-MOD1 took 0.019s (StdLUT)
# L8_OLI/B8 ACOLITE-LUT-202110-MOD2 took 0.020s (StdLUT)
# Choosing best fitting model: min_drmsd (2 bands)
# Computing RMSD for model ACOLITE-LUT-202110-MOD1
# Computing RMSD for model ACOLITE-LUT-202110-MOD1: 4.6774e-03
# Computing RMSD for model ACOLITE-LUT-202110-MOD2
# Computing RMSD for model ACOLITE-LUT-202110-MOD2: 4.0376e-04
# Selected model ACOLITE-LUT-202110-MOD2: aot 0.075, RMSD 4.04e-04
# Reshaping pressure to 101x101
# Reshaping wind to 101x101
# use_revlut True
# Wrote rhot_443
# Computing surface reflectance 1 443 0.998
# Wrote rhos_443
# L8_OLI/B1 took 0.3s (RevLUT)
# Wrote rhot_483
# Computing surface reflectance 2 483 0.988
# Wrote rhos_483
# L8_OLI/B2 took 0.3s (RevLUT)
# Wrote rhot_561
# Computing surface reflectance 3 561 0.933
# Wrote rhos_561
# L8_OLI/B3 took 0.3s (RevLUT)
# Wrote rhot_655
# Computing surface reflectance 4 655 0.954
# Wrote rhos_655
# L8_OLI/B4 took 0.3s (RevLUT)
# Wrote rhot_865
# Computing surface reflectance 5 865 0.997
# Wrote rhos_865
# L8_OLI/B5 took 0.3s (RevLUT)
# Wrote rhot_1609
# Computing surface reflectance 6 1609 0.965
# Wrote rhos_1609
# L8_OLI/B6 took 0.3s (RevLUT)
# Wrote rhot_2201
# Computing surface reflectance 7 2201 0.922
# Wrote rhos_2201
# L8_OLI/B7 took 0.3s (RevLUT)
# Wrote rhot_592
# Computing surface reflectance 8 592 0.940
# Wrote rhos_592
# L8_OLI/B8 took 0.3s (RevLUT)
# Wrote rhot_1373
# Computing orange band
# Wrote rhos_613
# Wrote /content/drive/MyDrive/Graduationproject/output_acolite/L8_OLI_2022_05_13_03_46_51_131042_GEM_L2R.nc
# Writing lon
# Writing lat
# Writing Rrs_443
# Writing Rrs_483
# Writing Rrs_561
# Writing Rrs_655
# Writing Rrs_865
# Writing Rrs_1609
# Writing Rrs_2201
# Writing Rrs_592
# Writing Rrs_613
# gem.data <bound method gem.data of <acolite.gem.gem.gem object at 0x7f2f8acf66d0>>
# gem.datasets ['lon', 'lat', 'saa', 'sza', 'vaa', 'vza', 'raa', 'rhot_443', 'rhot_483', 'rhot_561', 'rhot_655', 'rhot_865', 'rhot_1609', 'rhot_2201', 'rhot_592', 'rhot_1373', 'bt10', 'bt11']
# Running acolite for /content/drive/MyDrive/Graduationproject/input_nc/25N939853_100E175298_100px/L8_OLI_2022_05_29_03_46_53_131042_GEM_L1R.nc
# gem.gatts {'generated_by': 'ACOLITE', 'generated_on': '2022-09-04 05:38:54 UTC', 'contact': 'Quinten Vanhellemont', 'product_type': 'NetCDF', 'metadata_profile': 'beam', 'metadata_version': '0.5', 'auto_grouping': 'rhot:rhorc:rhos:rhow:Rrs', 'Conventions': 'CF-1.7', 'sensor': 'L8_OLI', 'vza': 0, 'sza': 20.79556352, 'raa': 19.160011, 'isodate': '2022-05-29T03:46:53.288834+00:00', 'pid': 'LC08_L1TP_131042_20220529_20220603_02_T1', 'se_distance': 1.01351481105531, 'oname': 'L8_OLI_2022_05_29_03_46_53', 'ofile': '/content/drive/MyDrive/Graduationproject/input_nc/25N939853_100E175298_100px/L8_OLI_2022_05_29_03_46_53_131042_GEM_L1R.nc', 'CLOUD_COVER': 23.93, 'CLOUD_COVER_LAND': 23.93, 'COLLECTION_CATEGORY': 'T1', 'COLLECTION_NUMBER': 2, 'DATA_SOURCE_ELEVATION': 'GLS2000', 'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS', 'DATE_ACQUIRED': '2022-05-29', 'DATE_PRODUCT_GENERATED': 1654237068000, 'DATUM': 'WGS84', 'EARTH_SUN_DISTANCE': 1.0135053, 'ELLIPSOID': 'WGS84', 'GEOMETRIC_RMSE_MODEL': 8.76, 'GEOMETRIC_RMSE_MODEL_X': 5.208, 'GEOMETRIC_RMSE_MODEL_Y': 7.044, 'GEOMETRIC_RMSE_VERIFY': 8.28, 'GRID_CELL_SIZE_PANCHROMATIC': 15, 'GRID_CELL_SIZE_REFLECTIVE': 30, 'GRID_CELL_SIZE_THERMAL': 30, 'GROUND_CONTROL_POINTS_MODEL': 306, 'GROUND_CONTROL_POINTS_VERIFY': 106, 'GROUND_CONTROL_POINTS_VERSION': 5, 'IMAGE_QUALITY_OLI': 9, 'IMAGE_QUALITY_TIRS': 9, 'K1_CONSTANT_BAND_10': 774.8853, 'K1_CONSTANT_BAND_11': 480.8883, 'K2_CONSTANT_BAND_10': 1321.0789, 'K2_CONSTANT_BAND_11': 1201.1442, 'LANDSAT_PRODUCT_ID': 'LC08_L1TP_131042_20220529_20220603_02_T1', 'LANDSAT_SCENE_ID': 'LC81310422022149LGN00', 'MAP_PROJECTION': 'UTM', 'NADIR_OFFNADIR': 'NADIR', 'ORIENTATION': 'NORTH_UP', 'PANCHROMATIC_LINES': 15461, 'PANCHROMATIC_SAMPLES': 15161, 'PROCESSING_LEVEL': 'L1TP', 'PROCESSING_SOFTWARE_VERSION': 'LPGS_15.6.0', 'RADIANCE_ADD_BAND_1': -61.11683, 'RADIANCE_ADD_BAND_10': 0.1, 'RADIANCE_ADD_BAND_11': 0.1, 'RADIANCE_ADD_BAND_2': -62.58437, 'RADIANCE_ADD_BAND_3': -57.67097, 'RADIANCE_ADD_BAND_4': -48.63141, 'RADIANCE_ADD_BAND_5': -29.76, 'RADIANCE_ADD_BAND_6': -7.40104, 'RADIANCE_ADD_BAND_7': -2.49455, 'RADIANCE_ADD_BAND_8': -55.03737, 'RADIANCE_ADD_BAND_9': -11.63088, 'RADIANCE_MULT_BAND_1': 0.012223, 'RADIANCE_MULT_BAND_10': 0.0003342, 'RADIANCE_MULT_BAND_11': 0.0003342, 'RADIANCE_MULT_BAND_2': 0.012517, 'RADIANCE_MULT_BAND_3': 0.011534, 'RADIANCE_MULT_BAND_4': 0.0097263, 'RADIANCE_MULT_BAND_5': 0.005952, 'RADIANCE_MULT_BAND_6': 0.0014802, 'RADIANCE_MULT_BAND_7': 0.00049891, 'RADIANCE_MULT_BAND_8': 0.011007, 'RADIANCE_MULT_BAND_9': 0.0023262, 'REFLECTANCE_ADD_BAND_1': -0.1, 'REFLECTANCE_ADD_BAND_2': -0.1, 'REFLECTANCE_ADD_BAND_3': -0.1, 'REFLECTANCE_ADD_BAND_4': -0.1, 'REFLECTANCE_ADD_BAND_5': -0.1, 'REFLECTANCE_ADD_BAND_6': -0.1, 'REFLECTANCE_ADD_BAND_7': -0.1, 'REFLECTANCE_ADD_BAND_8': -0.1, 'REFLECTANCE_ADD_BAND_9': -0.1, 'REFLECTANCE_MULT_BAND_1': 2e-05, 'REFLECTANCE_MULT_BAND_2': 2e-05, 'REFLECTANCE_MULT_BAND_3': 2e-05, 'REFLECTANCE_MULT_BAND_4': 2e-05, 'REFLECTANCE_MULT_BAND_5': 2e-05, 'REFLECTANCE_MULT_BAND_6': 2e-05, 'REFLECTANCE_MULT_BAND_7': 2e-05, 'REFLECTANCE_MULT_BAND_8': 2e-05, 'REFLECTANCE_MULT_BAND_9': 2e-05, 'REFLECTIVE_LINES': 7731, 'REFLECTIVE_SAMPLES': 7581, 'REQUEST_ID': 'P701fu3d39kfk_00035', 'RESAMPLING_OPTION': 'CUBIC_CONVOLUTION', 'ROLL_ANGLE': -0.001, 'SATURATION_BAND_1': 'Y', 'SATURATION_BAND_2': 'Y', 'SATURATION_BAND_3': 'Y', 'SATURATION_BAND_4': 'Y', 'SATURATION_BAND_5': 'Y', 'SATURATION_BAND_6': 'Y', 'SATURATION_BAND_7': 'Y', 'SATURATION_BAND_8': 'N', 'SATURATION_BAND_9': 'N', 'SCENE_CENTER_TIME': '03:46:53.2888340Z', 'SENSOR_ID': 'OLI_TIRS', 'SPACECRAFT_ID': 'LANDSAT_8', 'STATION_ID': 'LGN', 'SUN_AZIMUTH': 97.46821841, 'SUN_ELEVATION': 69.20443648, 'TARGET_WRS_PATH': 131, 'TARGET_WRS_ROW': 42, 'THERMAL_LINES': 7731, 'THERMAL_SAMPLES': 7581, 'TIRS_SSM_MODEL': 'FINAL', 'TIRS_SSM_POSITION_STATUS': 'ESTIMATED', 'TRUNCATION_OLI': 'UPPER', 'UTM_ZONE': 47, 'WRS_PATH': 131, 'WRS_ROW': 42, 'WRS_TYPE': 2, 'system:asset_size': 1359529550,  ...
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202214900_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202214906_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202214912_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202214918_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202215000_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202214900_O3_AURAOMI_24h.hdf
# gem.datasets ['lon', 'lat', 'saa', 'sza', 'vaa', 'vza', 'raa', 'rhot_443', 'rhot_483', 'rhot_561', 'rhot_655', 'rhot_865', 'rhot_1609', 'rhot_2201', 'rhot_592', 'rhot_1373', 'bt10', 'bt11']
# geom_mean {'sza': 20.958666, 'vza': 1.798657, 'raa': 32.03202, 'pressure': 1013.25, 'wind': 2.0}
# tg_dict {'wave': {'1': 442.98228442313956, '2': 482.58886817501445, '3': 561.332141645918, '4': 654.6055091346833, '5': 864.5708275848937, '6': 1609.090508782215, '7': 2201.2483359785456, '8': 591.6667966035536, '9': 1373.4761690438504}, 'tt_h2o': {'1': 1.0, '2': 1.0, '3': 0.99531170469793, '4': 0.9909464985433828, '5': 0.9981002087056454, '6': 0.9981044979231909, '7': 0.9665844772539851, '8': 0.9936175452402938, '9': 0.008657781280255959}, 'tt_o3': {'1': 0.9982104517762809, '2': 0.9877660026838001, '3': 0.9374053308132788, '4': 0.9624243576840316, '5': 0.9986153303376494, '6': 1.0, '7': 1.0, '8': 0.9468055416081042, '9': 1.0}, 'tt_o2': {'1': 1.0, '2': 1.0, '3': 1.0, '4': 0.9999914751399811, '5': 0.999956337599838, '6': 1.0, '7': 1.0, '8': 0.9996246089867697, '9': 1.0}, 'tt_co2': {'1': 1.0, '2': 1.0, '3': 1.0, '4': 1.0, '5': 1.0, '6': 0.9731133306324635, '7': 0.9990759738854557, '8': 1.0, '9': 0.9999790989761611}, 'tt_n2o': {'1': 1.0, '2': 1.0, '3': 1.0, '4': 1.0, '5': 1.0, '6': 1.0, '7': 0.9964181529566564, '8': 1.0, '9': 1.0}, 'tt_ch4': {'1': 1.0, '2': 1.0, '3': 1.0, '4': 1.0, '5': 1.0, '6': 0.9937057043986546, '7': 0.9588047374430263, '8': 1.0, '9': 1.0}, 'tt_gas': {'1': 0.9982104517762809, '2': 0.9877660026838001, '3': 0.93305789652752, '4': 0.9537174455046411, '5': 0.9966758802777903, '6': 0.9650277828767829, '7': 0.9218299227948471, '8': 0.9404629055373754, '9': 0.008657450656264892}}
# Using DSF atmospheric correction
# Scene too small for tiling (1x1 tiles of 200x200 pixels), using fixed processing
# Writing lon
# Wrote lon
# Writing lat
# Wrote lat
# Writing sza
# Wrote sza
# Writing vza
# Wrote vza
# Writing raa
# Wrote raa
# Loading LUTs
# romix+rsky_t True
# Loading LUTs took 2.8 s
# 1 rhot_443
# 1 intercept 0.092
# L8_OLI/B1 ACOLITE-LUT-202110-MOD1 took 0.008s (StdLUT)
# L8_OLI/B1 ACOLITE-LUT-202110-MOD2 took 0.010s (StdLUT)
# 2 rhot_483
# 2 intercept 0.072
# L8_OLI/B2 ACOLITE-LUT-202110-MOD1 took 0.010s (StdLUT)
# L8_OLI/B2 ACOLITE-LUT-202110-MOD2 took 0.008s (StdLUT)
# 3 rhot_561
# 3 intercept 0.050
# L8_OLI/B3 ACOLITE-LUT-202110-MOD1 took 0.008s (StdLUT)
# L8_OLI/B3 ACOLITE-LUT-202110-MOD2 took 0.008s (StdLUT)
# 4 rhot_655
# 4 intercept 0.035
# L8_OLI/B4 ACOLITE-LUT-202110-MOD1 took 0.023s (StdLUT)
# L8_OLI/B4 ACOLITE-LUT-202110-MOD2 took 0.011s (StdLUT)
# 5 rhot_865
# 5 intercept 0.020
# L8_OLI/B5 ACOLITE-LUT-202110-MOD1 took 0.026s (StdLUT)
# L8_OLI/B5 ACOLITE-LUT-202110-MOD2 took 0.022s (StdLUT)
# 6 rhot_1609
# 6 intercept 0.008
# L8_OLI/B6 ACOLITE-LUT-202110-MOD1 took 0.018s (StdLUT)
# L8_OLI/B6 ACOLITE-LUT-202110-MOD2 took 0.020s (StdLUT)
# 7 rhot_2201
# 7 intercept 0.005
# L8_OLI/B7 ACOLITE-LUT-202110-MOD1 took 0.022s (StdLUT)
# L8_OLI/B7 ACOLITE-LUT-202110-MOD2 took 0.009s (StdLUT)
# 8 rhot_592
# 8 intercept 0.044
# L8_OLI/B8 ACOLITE-LUT-202110-MOD1 took 0.021s (StdLUT)
# L8_OLI/B8 ACOLITE-LUT-202110-MOD2 took 0.015s (StdLUT)
# Choosing best fitting model: min_drmsd (2 bands)
# Computing RMSD for model ACOLITE-LUT-202110-MOD1
# Computing RMSD for model ACOLITE-LUT-202110-MOD1: 4.6062e-03
# Computing RMSD for model ACOLITE-LUT-202110-MOD2
# Computing RMSD for model ACOLITE-LUT-202110-MOD2: 4.6010e-03
# Selected model ACOLITE-LUT-202110-MOD2: aot 0.002, RMSD 4.60e-03
# Reshaping pressure to 101x101
# Reshaping wind to 101x101
# use_revlut True
# Wrote rhot_443
# Computing surface reflectance 1 443 0.998
# Wrote rhos_443
# L8_OLI/B1 took 0.3s (RevLUT)
# Wrote rhot_483
# Computing surface reflectance 2 483 0.988
# Wrote rhos_483
# L8_OLI/B2 took 0.3s (RevLUT)
# Wrote rhot_561
# Computing surface reflectance 3 561 0.933
# Wrote rhos_561
# L8_OLI/B3 took 0.3s (RevLUT)
# Wrote rhot_655
# Computing surface reflectance 4 655 0.954
# Wrote rhos_655
# L8_OLI/B4 took 0.3s (RevLUT)
# Wrote rhot_865
# Computing surface reflectance 5 865 0.997
# Wrote rhos_865
# L8_OLI/B5 took 0.3s (RevLUT)
# Wrote rhot_1609
# Computing surface reflectance 6 1609 0.965
# Wrote rhos_1609
# L8_OLI/B6 took 0.3s (RevLUT)
# Wrote rhot_2201
# Computing surface reflectance 7 2201 0.922
# Wrote rhos_2201
# L8_OLI/B7 took 0.3s (RevLUT)
# Wrote rhot_592
# Computing surface reflectance 8 592 0.940
# Wrote rhos_592
# L8_OLI/B8 took 0.3s (RevLUT)
# Wrote rhot_1373
# Computing orange band
# Wrote rhos_613
# Wrote /content/drive/MyDrive/Graduationproject/output_acolite/L8_OLI_2022_05_29_03_46_53_131042_GEM_L2R.nc
# Writing lon
# Writing lat
# Writing Rrs_443
# Writing Rrs_483
# Writing Rrs_561
# Writing Rrs_655
# Writing Rrs_865
# Writing Rrs_1609
# Writing Rrs_2201
# Writing Rrs_592
# Writing Rrs_613
# gem.data <bound method gem.data of <acolite.gem.gem.gem object at 0x7f2f914c8650>>
# gem.datasets ['lon', 'lat', 'saa', 'sza', 'vaa', 'vza', 'raa', 'rhot_443', 'rhot_483', 'rhot_561', 'rhot_655', 'rhot_865', 'rhot_1609', 'rhot_2201', 'rhot_592', 'rhot_1373', 'bt10', 'bt11']
# Running acolite for /content/drive/MyDrive/Graduationproject/input_nc/25N939853_100E175298_100px/L8_OLI_2022_07_16_03_47_09_131042_GEM_L1R.nc
# gem.gatts {'generated_by': 'ACOLITE', 'generated_on': '2022-09-04 05:38:56 UTC', 'contact': 'Quinten Vanhellemont', 'product_type': 'NetCDF', 'metadata_profile': 'beam', 'metadata_version': '0.5', 'auto_grouping': 'rhot:rhorc:rhos:rhow:Rrs', 'Conventions': 'CF-1.7', 'sensor': 'L8_OLI', 'vza': 0, 'sza': 22.735096889999994, 'raa': 21.063034, 'isodate': '2022-07-16T03:47:09.866980+00:00', 'pid': 'LC08_L1TP_131042_20220716_20220726_02_T1', 'se_distance': 1.0164285897449878, 'oname': 'L8_OLI_2022_07_16_03_47_09', 'ofile': '/content/drive/MyDrive/Graduationproject/input_nc/25N939853_100E175298_100px/L8_OLI_2022_07_16_03_47_09_131042_GEM_L1R.nc', 'CLOUD_COVER': 27.62, 'CLOUD_COVER_LAND': 27.62, 'COLLECTION_CATEGORY': 'T1', 'COLLECTION_NUMBER': 2, 'DATA_SOURCE_ELEVATION': 'GLS2000', 'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS', 'DATE_ACQUIRED': '2022-07-16', 'DATE_PRODUCT_GENERATED': 1658798650000, 'DATUM': 'WGS84', 'EARTH_SUN_DISTANCE': 1.0164031, 'ELLIPSOID': 'WGS84', 'GEOMETRIC_RMSE_MODEL': 8.624, 'GEOMETRIC_RMSE_MODEL_X': 5.596, 'GEOMETRIC_RMSE_MODEL_Y': 6.562, 'GEOMETRIC_RMSE_VERIFY': 10.258, 'GRID_CELL_SIZE_PANCHROMATIC': 15, 'GRID_CELL_SIZE_REFLECTIVE': 30, 'GRID_CELL_SIZE_THERMAL': 30, 'GROUND_CONTROL_POINTS_MODEL': 248, 'GROUND_CONTROL_POINTS_VERIFY': 128, 'GROUND_CONTROL_POINTS_VERSION': 5, 'IMAGE_QUALITY_OLI': 9, 'IMAGE_QUALITY_TIRS': 9, 'K1_CONSTANT_BAND_10': 774.8853, 'K1_CONSTANT_BAND_11': 480.8883, 'K2_CONSTANT_BAND_10': 1321.0789, 'K2_CONSTANT_BAND_11': 1201.1442, 'LANDSAT_PRODUCT_ID': 'LC08_L1TP_131042_20220716_20220726_02_T1', 'LANDSAT_SCENE_ID': 'LC81310422022197LGN00', 'MAP_PROJECTION': 'UTM', 'NADIR_OFFNADIR': 'NADIR', 'ORIENTATION': 'NORTH_UP', 'PANCHROMATIC_LINES': 15461, 'PANCHROMATIC_SAMPLES': 15161, 'PROCESSING_LEVEL': 'L1TP', 'PROCESSING_SOFTWARE_VERSION': 'LPGS_16.1.0', 'RADIANCE_ADD_BAND_1': -60.76883, 'RADIANCE_ADD_BAND_10': 0.1, 'RADIANCE_ADD_BAND_11': 0.1, 'RADIANCE_ADD_BAND_2': -62.22802, 'RADIANCE_ADD_BAND_3': -57.34259, 'RADIANCE_ADD_BAND_4': -48.3545, 'RADIANCE_ADD_BAND_5': -29.59054, 'RADIANCE_ADD_BAND_6': -7.3589, 'RADIANCE_ADD_BAND_7': -2.48034, 'RADIANCE_ADD_BAND_8': -54.72399, 'RADIANCE_ADD_BAND_9': -11.56466, 'RADIANCE_MULT_BAND_1': 0.012154, 'RADIANCE_MULT_BAND_10': 0.0003342, 'RADIANCE_MULT_BAND_11': 0.0003342, 'RADIANCE_MULT_BAND_2': 0.012446, 'RADIANCE_MULT_BAND_3': 0.011469, 'RADIANCE_MULT_BAND_4': 0.0096709, 'RADIANCE_MULT_BAND_5': 0.0059181, 'RADIANCE_MULT_BAND_6': 0.0014718, 'RADIANCE_MULT_BAND_7': 0.00049607, 'RADIANCE_MULT_BAND_8': 0.010945, 'RADIANCE_MULT_BAND_9': 0.0023129, 'REFLECTANCE_ADD_BAND_1': -0.1, 'REFLECTANCE_ADD_BAND_2': -0.1, 'REFLECTANCE_ADD_BAND_3': -0.1, 'REFLECTANCE_ADD_BAND_4': -0.1, 'REFLECTANCE_ADD_BAND_5': -0.1, 'REFLECTANCE_ADD_BAND_6': -0.1, 'REFLECTANCE_ADD_BAND_7': -0.1, 'REFLECTANCE_ADD_BAND_8': -0.1, 'REFLECTANCE_ADD_BAND_9': -0.1, 'REFLECTANCE_MULT_BAND_1': 2e-05, 'REFLECTANCE_MULT_BAND_2': 2e-05, 'REFLECTANCE_MULT_BAND_3': 2e-05, 'REFLECTANCE_MULT_BAND_4': 2e-05, 'REFLECTANCE_MULT_BAND_5': 2e-05, 'REFLECTANCE_MULT_BAND_6': 2e-05, 'REFLECTANCE_MULT_BAND_7': 2e-05, 'REFLECTANCE_MULT_BAND_8': 2e-05, 'REFLECTANCE_MULT_BAND_9': 2e-05, 'REFLECTIVE_LINES': 7731, 'REFLECTIVE_SAMPLES': 7581, 'REQUEST_ID': '1556554_02647', 'RESAMPLING_OPTION': 'CUBIC_CONVOLUTION', 'ROLL_ANGLE': -0.001, 'SATURATION_BAND_1': 'Y', 'SATURATION_BAND_2': 'Y', 'SATURATION_BAND_3': 'Y', 'SATURATION_BAND_4': 'Y', 'SATURATION_BAND_5': 'Y', 'SATURATION_BAND_6': 'Y', 'SATURATION_BAND_7': 'Y', 'SATURATION_BAND_8': 'N', 'SATURATION_BAND_9': 'N', 'SCENE_CENTER_TIME': '03:47:09.8669800Z', 'SENSOR_ID': 'OLI_TIRS', 'SPACECRAFT_ID': 'LANDSAT_8', 'STATION_ID': 'LGN', 'SUN_AZIMUTH': 96.57737557, 'SUN_ELEVATION': 67.26490311, 'TARGET_WRS_PATH': 131, 'TARGET_WRS_ROW': 42, 'THERMAL_LINES': 7731, 'THERMAL_SAMPLES': 7581, 'TIRS_SSM_MODEL': 'FINAL', 'TIRS_SSM_POSITION_STATUS': 'ESTIMATED', 'TRUNCATION_OLI': 'UPPER', 'UTM_ZONE': 47, 'WRS_PATH': 131, 'WRS_ROW': 42, 'WRS_TYPE': 2, 'system:asset_size': 1349 ...
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202219700_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202219706_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202219712_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202219718_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202219800_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202219700_O3_AURAOMI_24h.hdf
# gem.datasets ['lon', 'lat', 'saa', 'sza', 'vaa', 'vza', 'raa', 'rhot_443', 'rhot_483', 'rhot_561', 'rhot_655', 'rhot_865', 'rhot_1609', 'rhot_2201', 'rhot_592', 'rhot_1373', 'bt10', 'bt11']
# ...
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202208500_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202208506_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202208512_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202208518_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202208600_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202208500_O3_AURAOMI_24h.hdf
# gem.datasets ['lon', 'lat', 'saa', 'sza', 'vaa', 'vza', 'raa', 'rhot_443', 'rhot_483', 'rhot_561', 'rhot_655', 'rhot_865', 'rhot_1609', 'rhot_2201', 'rhot_592', 'rhot_1373', 'bt10', 'bt11']
# geom_mean {'sza': 33.508545, 'vza': 1.6978071, 'raa': 1.1193266, 'pressure': 1013.25, 'wind': 2.0}
# tg_dict {'wave': {'1': 442.98228442313956, '2': 482.58886817501445, '3': 561.332141645918, '4': 654.6055091346833, '5': 864.5708275848937, '6': 1609.090508782215, '7': 2201.2483359785456, '8': 591.6667966035536, '9': 1373.4761690438504}, 'tt_h2o': {'1': 1.0, '2': 1.0, '3': 0.995013734141741, '4': 0.9903649321160641, '5': 0.9979671357693264, '6': 0.9979694636627559, '7': 0.9647855927837227, '8': 0.9932115341244746, '9': 0.007565748305837865}, 'tt_o3': {'1': 0.9980996153201439, '2': 0.9870143158351405, '3': 0.9336604994162845, '4': 0.9601437044366068, '5': 0.9985295588471123, '6': 1.0, '7': 1.0, '8': 0.9436141545215271, '9': 1.0}, 'tt_o2': {'1': 1.0, '2': 1.0, '3': 1.0, '4': 0.999990831384375, '5': 0.9999536255009521, '6': 1.0, '7': 1.0, '8': 0.9996080155741645, '9': 1.0}, 'tt_co2': {'1': 1.0, '2': 1.0, '3': 1.0, '4': 1.0, '5': 1.0, '6': 0.9718658232909567, '7': 0.9990310940581035, '8': 1.0, '9': 0.9999777968820346}, 'tt_n2o': {'1': 1.0, '2': 1.0, '3': 1.0, '4': 1.0, '5': 1.0, '6': 1.0, '7': 0.9962052736361469, '8': 1.0, '9': 1.0}, 'tt_ch4': {'1': 1.0, '2': 1.0, '3': 1.0, '4': 1.0, '5': 1.0, '6': 0.9933575315115067, '7': 0.9567539594584377, '8': 1.0, '9': 1.0}, 'tt_gas': {'1': 0.9980996153201439, '2': 0.9870143158351405, '3': 0.929058386261448, '4': 0.9509003623913557, '5': 0.9964548687321483, '6': 0.9633094277355341, '7': 0.9178264816634049, '8': 0.9369012361895015, '9': 0.00756543694817567}}
# Using DSF atmospheric correction
# Scene too small for tiling (1x1 tiles of 200x200 pixels), using fixed processing
# Writing lon
# Wrote lon
# Writing lat
# Wrote lat
# Writing sza
# Wrote sza
# Writing vza
# Wrote vza
# Writing raa
# Wrote raa
# Loading LUTs
# romix+rsky_t True
# Loading LUTs took 2.2 s
# 1 rhot_443
# 1 intercept 0.729
# L8_OLI/B1 ACOLITE-LUT-202110-MOD1 took 0.020s (StdLUT)
# L8_OLI/B1 ACOLITE-LUT-202110-MOD2 took 0.021s (StdLUT)
# 2 rhot_483
# 2 intercept 0.715
# L8_OLI/B2 ACOLITE-LUT-202110-MOD1 took 0.015s (StdLUT)
# L8_OLI/B2 ACOLITE-LUT-202110-MOD2 took 0.021s (StdLUT)
# 3 rhot_561
# 3 intercept 0.654
# L8_OLI/B3 ACOLITE-LUT-202110-MOD1 took 0.009s (StdLUT)
# L8_OLI/B3 ACOLITE-LUT-202110-MOD2 took 0.009s (StdLUT)
# 4 rhot_655
# 4 intercept 0.662
# L8_OLI/B4 ACOLITE-LUT-202110-MOD1 took 0.022s (StdLUT)
# L8_OLI/B4 ACOLITE-LUT-202110-MOD2 took 0.018s (StdLUT)
# 5 rhot_865
# 5 intercept 0.671
# L8_OLI/B5 ACOLITE-LUT-202110-MOD1 took 0.022s (StdLUT)
# L8_OLI/B5 ACOLITE-LUT-202110-MOD2 took 0.022s (StdLUT)
# 6 rhot_1609
# 6 intercept 0.341
# L8_OLI/B6 ACOLITE-LUT-202110-MOD1 took 0.010s (StdLUT)
# L8_OLI/B6 ACOLITE-LUT-202110-MOD2 took 0.009s (StdLUT)
# 7 rhot_2201
# 7 intercept 0.257
# L8_OLI/B7 ACOLITE-LUT-202110-MOD1 took 0.011s (StdLUT)
# L8_OLI/B7 ACOLITE-LUT-202110-MOD2 took 0.015s (StdLUT)
# 8 rhot_592
# 8 intercept 0.665
# L8_OLI/B8 ACOLITE-LUT-202110-MOD1 took 0.009s (StdLUT)
# L8_OLI/B8 ACOLITE-LUT-202110-MOD2 took 0.008s (StdLUT)
# Choosing best fitting model: min_drmsd (2 bands)
# Computing RMSD for model ACOLITE-LUT-202110-MOD1
# Computing RMSD for model ACOLITE-LUT-202110-MOD1: 6.4629e-01
# Computing RMSD for model ACOLITE-LUT-202110-MOD2
# Computing RMSD for model ACOLITE-LUT-202110-MOD2: 6.4621e-01
# Selected model ACOLITE-LUT-202110-MOD2: aot 0.010, RMSD 6.46e-01
# Reshaping pressure to 101x101
# Reshaping wind to 101x101
# use_revlut True
# Wrote rhot_443
# Computing surface reflectance 1 443 0.998
# Wrote rhos_443
# L8_OLI/B1 took 0.3s (RevLUT)
# Wrote rhot_483
# Computing surface reflectance 2 483 0.987
# Wrote rhos_483
# L8_OLI/B2 took 0.4s (RevLUT)
# Wrote rhot_561
# Computing surface reflectance 3 561 0.929
# Wrote rhos_561
# L8_OLI/B3 took 0.4s (RevLUT)
# Wrote rhot_655
# Computing surface reflectance 4 655 0.951
# Wrote rhos_655
# L8_OLI/B4 took 0.4s (RevLUT)
# Wrote rhot_865
# Computing surface reflectance 5 865 0.996
# Wrote rhos_865
# L8_OLI/B5 took 0.4s (RevLUT)
# Wrote rhot_1609
# Computing surface reflectance 6 1609 0.963
# Wrote rhos_1609
# L8_OLI/B6 took 0.4s (RevLUT)
# Wrote rhot_2201
# Computing surface reflectance 7 2201 0.918
# Wrote rhos_2201
# L8_OLI/B7 took 0.4s (RevLUT)
# Wrote rhot_592
# Computing surface reflectance 8 592 0.937
# Wrote rhos_592
# L8_OLI/B8 took 0.4s (RevLUT)
# Wrote rhot_1373
# Computing orange band
# Wrote rhos_613
# Wrote /content/drive/MyDrive/Graduationproject/output_acolite/L8_OLI_2022_03_26_03_46_44_131042_GEM_L2R.nc
# Writing lon
# Writing lat
# Writing Rrs_443
# Writing Rrs_483
# Writing Rrs_561
# Writing Rrs_655
# Writing Rrs_865
# Writing Rrs_1609
# Writing Rrs_2201
# Writing Rrs_592
# Writing Rrs_613
# gem.data <bound method gem.data of <acolite.gem.gem.gem object at 0x7f2f86e167d0>>
# gem.datasets ['lon', 'lat', 'saa', 'sza', 'vaa', 'vza', 'raa', 'rhot_443', 'rhot_483', 'rhot_561', 'rhot_655', 'rhot_865', 'rhot_1609', 'rhot_2201', 'rhot_592', 'rhot_1373', 'bt10', 'bt11']
# Running acolite for /content/drive/MyDrive/Graduationproject/input_nc/25N939853_100E175298_100px/L8_OLI_2022_06_30_03_47_11_131042_GEM_L1R.nc
# gem.gatts {'generated_by': 'ACOLITE', 'generated_on': '2022-09-04 05:40:18 UTC', 'contact': 'Quinten Vanhellemont', 'product_type': 'NetCDF', 'metadata_profile': 'beam', 'metadata_version': '0.5', 'auto_grouping': 'rhot:rhorc:rhos:rhow:Rrs', 'Conventions': 'CF-1.7', 'sensor': 'L8_OLI', 'vza': 0, 'sza': 21.762184649999995, 'raa': 20.298103, 'isodate': '2022-06-30T03:47:11.219965+00:00', 'pid': 'LC08_L1GT_131042_20220630_20220707_02_T2', 'se_distance': 1.0166470663626899, 'oname': 'L8_OLI_2022_06_30_03_47_11', 'ofile': '/content/drive/MyDrive/Graduationproject/input_nc/25N939853_100E175298_100px/L8_OLI_2022_06_30_03_47_11_131042_GEM_L1R.nc', 'CLOUD_COVER': 98.55, 'CLOUD_COVER_LAND': 98.55, 'COLLECTION_CATEGORY': 'T2', 'COLLECTION_NUMBER': 2, 'DATA_SOURCE_ELEVATION': 'GLS2000', 'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS', 'DATE_ACQUIRED': '2022-06-30', 'DATE_PRODUCT_GENERATED': 1657237863000, 'DATUM': 'WGS84', 'EARTH_SUN_DISTANCE': 1.0166663, 'ELLIPSOID': 'WGS84', 'GRID_CELL_SIZE_PANCHROMATIC': 15, 'GRID_CELL_SIZE_REFLECTIVE': 30, 'GRID_CELL_SIZE_THERMAL': 30, 'IMAGE_QUALITY_OLI': 9, 'IMAGE_QUALITY_TIRS': 9, 'K1_CONSTANT_BAND_10': 774.8853, 'K1_CONSTANT_BAND_11': 480.8883, 'K2_CONSTANT_BAND_10': 1321.0789, 'K2_CONSTANT_BAND_11': 1201.1442, 'LANDSAT_PRODUCT_ID': 'LC08_L1GT_131042_20220630_20220707_02_T2', 'LANDSAT_SCENE_ID': 'LC81310422022181LGN00', 'MAP_PROJECTION': 'UTM', 'NADIR_OFFNADIR': 'NADIR', 'ORIENTATION': 'NORTH_UP', 'PANCHROMATIC_LINES': 15461, 'PANCHROMATIC_SAMPLES': 15161, 'PROCESSING_LEVEL': 'L1GT', 'PROCESSING_SOFTWARE_VERSION': 'LPGS_16.1.0', 'RADIANCE_ADD_BAND_1': -60.73737, 'RADIANCE_ADD_BAND_10': 0.1, 'RADIANCE_ADD_BAND_11': 0.1, 'RADIANCE_ADD_BAND_2': -62.19581, 'RADIANCE_ADD_BAND_3': -57.31291, 'RADIANCE_ADD_BAND_4': -48.32947, 'RADIANCE_ADD_BAND_5': -29.57523, 'RADIANCE_ADD_BAND_6': -7.35509, 'RADIANCE_ADD_BAND_7': -2.47906, 'RADIANCE_ADD_BAND_8': -54.69566, 'RADIANCE_ADD_BAND_9': -11.55867, 'RADIANCE_MULT_BAND_1': 0.012147, 'RADIANCE_MULT_BAND_10': 0.0003342, 'RADIANCE_MULT_BAND_11': 0.0003342, 'RADIANCE_MULT_BAND_2': 0.012439, 'RADIANCE_MULT_BAND_3': 0.011463, 'RADIANCE_MULT_BAND_4': 0.0096659, 'RADIANCE_MULT_BAND_5': 0.005915, 'RADIANCE_MULT_BAND_6': 0.001471, 'RADIANCE_MULT_BAND_7': 0.00049581, 'RADIANCE_MULT_BAND_8': 0.010939, 'RADIANCE_MULT_BAND_9': 0.0023117, 'REFLECTANCE_ADD_BAND_1': -0.1, 'REFLECTANCE_ADD_BAND_2': -0.1, 'REFLECTANCE_ADD_BAND_3': -0.1, 'REFLECTANCE_ADD_BAND_4': -0.1, 'REFLECTANCE_ADD_BAND_5': -0.1, 'REFLECTANCE_ADD_BAND_6': -0.1, 'REFLECTANCE_ADD_BAND_7': -0.1, 'REFLECTANCE_ADD_BAND_8': -0.1, 'REFLECTANCE_ADD_BAND_9': -0.1, 'REFLECTANCE_MULT_BAND_1': 2e-05, 'REFLECTANCE_MULT_BAND_2': 2e-05, 'REFLECTANCE_MULT_BAND_3': 2e-05, 'REFLECTANCE_MULT_BAND_4': 2e-05, 'REFLECTANCE_MULT_BAND_5': 2e-05, 'REFLECTANCE_MULT_BAND_6': 2e-05, 'REFLECTANCE_MULT_BAND_7': 2e-05, 'REFLECTANCE_MULT_BAND_8': 2e-05, 'REFLECTANCE_MULT_BAND_9': 2e-05, 'REFLECTIVE_LINES': 7731, 'REFLECTIVE_SAMPLES': 7581, 'REQUEST_ID': '1550859_02321', 'RESAMPLING_OPTION': 'CUBIC_CONVOLUTION', 'ROLL_ANGLE': -0.001, 'SATURATION_BAND_1': 'Y', 'SATURATION_BAND_2': 'Y', 'SATURATION_BAND_3': 'Y', 'SATURATION_BAND_4': 'Y', 'SATURATION_BAND_5': 'Y', 'SATURATION_BAND_6': 'Y', 'SATURATION_BAND_7': 'Y', 'SATURATION_BAND_8': 'N', 'SATURATION_BAND_9': 'N', 'SCENE_CENTER_TIME': '03:47:11.2199650Z', 'SENSOR_ID': 'OLI_TIRS', 'SPACECRAFT_ID': 'LANDSAT_8', 'STATION_ID': 'LGN', 'SUN_AZIMUTH': 92.32152704, 'SUN_ELEVATION': 68.23781535, 'TARGET_WRS_PATH': 131, 'TARGET_WRS_ROW': 42, 'THERMAL_LINES': 7731, 'THERMAL_SAMPLES': 7581, 'TIRS_SSM_MODEL': 'FINAL', 'TIRS_SSM_POSITION_STATUS': 'ESTIMATED', 'TRUNCATION_OLI': 'UPPER', 'UTM_ZONE': 47, 'WRS_PATH': 131, 'WRS_ROW': 42, 'WRS_TYPE': 2, 'system:asset_size': 1331185093, 'system:index': '2_LC08_131042_20220630', 'system:time_end': 1656560831219, 'system:time_start': 1656560831219, 'xrange': array([616200., 619200.]), 'yrange': array([2871060., 2868060.]), 'proj4_string': '+proj=utm +zone=47 +datum= ...
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202218100_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202218106_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202218112_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202218118_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202218200_MET_NCEPR2_6h.hdf.bz2
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/N202218100_O3_AURAOMI_24h.hdf
# gem.datasets ['lon', 'lat', 'saa', 'sza', 'vaa', 'vza', 'raa', 'rhot_443', 'rhot_483', 'rhot_561', 'rhot_655', 'rhot_865', 'rhot_1609', 'rhot_2201', 'rhot_592', 'rhot_1373', 'bt10', 'bt11']
# geom_mean {'sza': 21.909758, 'vza': 1.6116519, 'raa': 40.56376, 'pressure': 1013.25, 'wind': 2.0}
# tg_dict {'wave': {'1': 442.98228442313956, '2': 482.58886817501445, '3': 561.332141645918, '4': 654.6055091346833, '5': 864.5708275848937, '6': 1609.090508782215, '7': 2201.2483359785456, '8': 591.6667966035536, '9': 1373.4761690438504}, 'tt_h2o': {'1': 1.0, '2': 1.0, '3': 0.9952896736659251, '4': 0.9909034987677416, '5': 0.9980903679908621, '6': 0.998094511806535, '7': 0.9664515034179483, '8': 0.9935875261250692, '9': 0.008577272541396789}, 'tt_o3': {'1': 0.9982044925700111, '2': 0.9877255698742088, '3': 0.9372036039179726, '4': 0.9623016000648091, '5': 0.9986107188020567, '6': 1.0, '7': 1.0, '8': 0.9466336543883221, '9': 1.0}, 'tt_o2': {'1': 1.0000000000000002, '2': 1.0000000000000002, '3': 1.0000000000000004, '4': 0.9999914385694211, '5': 0.9999561835951022, '6': 1.0000000000000002, '7': 1.0000000000000002, '8': 0.9996236604906399, '9': 1.0000000000000004}, 'tt_co2': {'1': 1.0000000000000002, '2': 1.0000000000000002, '3': 1.0000000000000004, '4': 1.0000000000000002, '5': 1.0000000000000002, '6': 0.9730420768471894, '7': 0.9990734181387865, '8': 1.0000000000000004, '9': 0.9999790257110289}, 'tt_n2o': {'1': 1.0000000000000002, '2': 1.0000000000000002, '3': 1.0000000000000004, '4': 1.0000000000000002, '5': 1.0000000000000002, '6': 1.0000000000000002, '7': 0.996406083451662, '8': 1.0000000000000004, '9': 1.0000000000000004}, 'tt_ch4': {'1': 1.0000000000000002, '2': 1.0000000000000002, '3': 1.0000000000000004, '4': 1.0000000000000002, '5': 1.0000000000000002, '6': 0.9936859138222927, '7': 0.9586877329508098, '8': 1.0000000000000004, '9': 1.0000000000000004}, 'tt_gas': {'1': 0.998204492570012, '2': 0.9877255698742096, '3': 0.9328368420054818, '4': 0.9535545053310743, '5': 0.996661308047766, '6': 0.9649275027760048, '7': 0.9215717266991431, '8': 0.9402632983086648, '9': 0.008576943531974711}}
# Using DSF atmospheric correction
# Scene too small for tiling (1x1 tiles of 200x200 pixels), using fixed processing
# Writing lon
# Wrote lon
# Writing lat
# Wrote lat
# Writing sza
# Wrote sza
# Writing vza
# Wrote vza
# Writing raa
# Wrote raa
# Loading LUTs
# romix+rsky_t True
# Loading LUTs took 2.3 s
# 1 rhot_443
# 1 intercept 0.677
# L8_OLI/B1 ACOLITE-LUT-202110-MOD1 took 0.009s (StdLUT)
# L8_OLI/B1 ACOLITE-LUT-202110-MOD2 took 0.010s (StdLUT)
# 2 rhot_483
# 2 intercept 0.675
# L8_OLI/B2 ACOLITE-LUT-202110-MOD1 took 0.008s (StdLUT)
# L8_OLI/B2 ACOLITE-LUT-202110-MOD2 took 0.008s (StdLUT)
# 3 rhot_561
# 3 intercept 0.639
# L8_OLI/B3 ACOLITE-LUT-202110-MOD1 took 0.014s (StdLUT)
# L8_OLI/B3 ACOLITE-LUT-202110-MOD2 took 0.019s (StdLUT)
# 4 rhot_655
# 4 intercept 0.653
# L8_OLI/B4 ACOLITE-LUT-202110-MOD1 took 0.010s (StdLUT)
# L8_OLI/B4 ACOLITE-LUT-202110-MOD2 took 0.023s (StdLUT)
# 5 rhot_865
# 5 intercept 0.702
# L8_OLI/B5 ACOLITE-LUT-202110-MOD1 took 0.017s (StdLUT)
# L8_OLI/B5 ACOLITE-LUT-202110-MOD2 took 0.010s (StdLUT)
# 6 rhot_1609
# 6 intercept 0.499
# L8_OLI/B6 ACOLITE-LUT-202110-MOD1 took 0.020s (StdLUT)
# L8_OLI/B6 ACOLITE-LUT-202110-MOD2 took 0.024s (StdLUT)
# 7 rhot_2201
# 7 intercept 0.350
# L8_OLI/B7 ACOLITE-LUT-202110-MOD1 took 0.021s (StdLUT)
# L8_OLI/B7 ACOLITE-LUT-202110-MOD2 took 0.012s (StdLUT)
# 8 rhot_592
# 8 intercept 0.646
# L8_OLI/B8 ACOLITE-LUT-202110-MOD1 took 0.023s (StdLUT)
# L8_OLI/B8 ACOLITE-LUT-202110-MOD2 took 0.009s (StdLUT)
# Choosing best fitting model: min_drmsd (2 bands)
# Computing RMSD for model ACOLITE-LUT-202110-MOD1
# Computing RMSD for model ACOLITE-LUT-202110-MOD1: 6.0139e-01
# Computing RMSD for model ACOLITE-LUT-202110-MOD2
# Computing RMSD for model ACOLITE-LUT-202110-MOD2: 6.0131e-01
# Selected model ACOLITE-LUT-202110-MOD2: aot 0.010, RMSD 6.01e-01
# Reshaping pressure to 101x101
# Reshaping wind to 101x101
# use_revlut True
# Wrote rhot_443
# Computing surface reflectance 1 443 0.998
# Wrote rhos_443
# L8_OLI/B1 took 0.3s (RevLUT)
# Wrote rhot_483
# Computing surface reflectance 2 483 0.988
# Wrote rhos_483
# L8_OLI/B2 took 0.3s (RevLUT)
# Wrote rhot_561
# Computing surface reflectance 3 561 0.933
# Wrote rhos_561
# L8_OLI/B3 took 0.3s (RevLUT)
# Wrote rhot_655
# Computing surface reflectance 4 655 0.954
# Wrote rhos_655
# L8_OLI/B4 took 0.3s (RevLUT)
# Wrote rhot_865
# Computing surface reflectance 5 865 0.997
# Wrote rhos_865
# L8_OLI/B5 took 0.3s (RevLUT)
# Wrote rhot_1609
# Computing surface reflectance 6 1609 0.965
# Wrote rhos_1609
# L8_OLI/B6 took 0.3s (RevLUT)
# Wrote rhot_2201
# Computing surface reflectance 7 2201 0.922
# Wrote rhos_2201
# L8_OLI/B7 took 0.3s (RevLUT)
# Wrote rhot_592
# Computing surface reflectance 8 592 0.940
# Wrote rhos_592
# L8_OLI/B8 took 0.3s (RevLUT)
# Wrote rhot_1373
# Computing orange band
# Wrote rhos_613
# Wrote /content/drive/MyDrive/Graduationproject/output_acolite/L8_OLI_2022_06_30_03_47_11_131042_GEM_L2R.nc
# Writing lon
# Writing lat
# Writing Rrs_443
# Writing Rrs_483
# Writing Rrs_561
# Writing Rrs_655
# Writing Rrs_865
# Writing Rrs_1609
# Writing Rrs_2201
# Writing Rrs_592
# Writing Rrs_613

# %% [markdown]
# **L5 波段**
#
# B1	30米	0.45 - 0.52 微米	蓝色的
#
# B2	30米	0.52 - 0.60 微米	绿色的
#
# B3	30米	0.63 - 0.69 微米	红色的
#
# B4	30米	0.76 - 0.90 微米	近红外
#
# B5	30米	1.55 - 1.75 微米	短波红外线 1
#
# B6	30米	10.40 - 12.50 微米	热红外 1. 从 60m 到 30m 重新采样。
#
# B7	30米	2.08 - 2.35 微米	短波红外线 2
#
# **L8 波段**
#
# B1	30米	0.43 - 0.45 微米	沿海气溶胶
#
# B2	30米	0.45 - 0.51 微米	蓝色的
#
# B3	30米	0.53 - 0.59 微米	绿色的
#
# B4	30米	0.64 - 0.67 微米	红色的
#
# B5	30米	0.85 - 0.88 微米	近红外
#
# B6	30米	1.57 - 1.65 微米	短波红外线 1
#
# B7	30米	2.11 - 2.29 微米	短波红外线 2
#
# B8	15米	0.52 - 0.90 微米	带 8 全色
#
# B9	15米	1.36 - 1.38 微米	卷云
#
# B10	30米	10.60 - 11.19 微米	热红外 1，从 100m 到 30m 重新采样
#
# B11	30米	11.50 - 12.51 微米	热红外 2，从 100m 重新采样到 30m
